# %% [markdown]
# # Database Queries and Analysis
# This notebook contains queries for various database tables, identifies potential data issues, and provides insights for further analysis.

# %%
# Import required libraries
import pandas as pd
import os
from utils import connect_to_db

# %%
# Query the `stock_metadata` table
conn = connect_to_db()
if conn:
    query = "SELECT * FROM core.stock_metadata;"
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    # Display the data
    display(df)
# Out:
# /var/folders/cp/knf70myd44x348nchr96hn9h0000gp/T/ipykernel_84630/3442289753.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#     tic                name             sector              industry  \
# 0  AAPL          Apple Inc.         Technology  Consumer Electronics
# 1  TSLA         Tesla, Inc.  Consumer Cyclical    Auto Manufacturers
# 2  NVDA  NVIDIA Corporation         Technology        Semiconductors
#
#          country     market_cap  employees  \
# 0  United States  3791126003712     150000
# 1  United States  1464396414976     125665
# 2  United States  4338392236032      36000
#
#                                          description                 website  \
# 0  Apple Inc. designs, manufactures, and markets ...   https://www.apple.com
# 1  Tesla, Inc. designs, develops, manufactures, l...   https://www.tesla.com
# 2  NVIDIA Corporation, a computing infrastructure...  https://www.nvidia.com
#
#   exchange currency                                            summary  \
# 0   NASDAQ      USD  Apple Inc. is a leading technology company tha...
# 1   NASDAQ      USD  Tesla, Inc. is a prominent manufacturer and pr...
# 2   NASDAQ      USD  NVIDIA Corporation is a technology company spe...
#
#                                        short_summary  \
# 0  Apple Inc. is a prominent technology company t...
# 1  Tesla, Inc. is a leading manufacturer of elect...
# 2  NVIDIA Corporation is a technology company foc...
#
#                 last_updated
# 0 2025-10-11 00:43:18.198221
# 1 2025-10-11 00:43:18.198221
# 2 2025-10-11 00:43:18.198221

# %%
# Query the `earnings_transcript_analysis` table
conn = connect_to_db()
if conn:
    query = "SELECT * FROM core.earnings_transcript_analysis;"
    df = pd.read_sql_query(query, conn)
    conn.close()
    
    # Display the data
    display(df)
# Out:
# /var/folders/cp/knf70myd44x348nchr96hn9h0000gp/T/ipykernel_84630/1101357188.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#     tic  fiscal_year  fiscal_quarter  sentiment  durability  \
# 0  AAPL         2024               4         -1           0
# 1  AAPL         2025               1          0           2
# 2  AAPL         2025               2          1           2
# 3  TSLA         2025               1         -1           1
# 4  TSLA         2025               2         -1           0
# 5  NVDA         2024               2          1           2
# 6  NVDA         2024               3          1           2
# 7  NVDA         2024               4         -1           1
# 8  NVDA         2025               1         -1           0
# 9  NVDA         2025               2          1           2
#
#                                  performance_factors  \
# 0  [foreign exchange headwinds, cost discipline, ...
# 1  [foreign exchange headwinds, strong Mac perfor...
# 2  [record revenue, strong services growth, iPhon...
# 3  [auto margins decline, lower deliveries, recor...
# 4  [tariff impacts, operating expenses growth, im...
# 5  [record revenue, strong demand, data center gr...
# 6  [record revenue, strong gaming demand, data ce...
# 7  [gross margin decline, higher operating expens...
# 8  [export controls, inventory write-down, data c...
# 9  [record gaming revenue, data center growth, st...
#
#                                         past_summary  guidance_direction  \
# 0  Management expressed concerns about foreign ex...                   0
# 1  Apple reported a revenue of $95.4 billion, up ...                   0
# 2  Apple reported a strong June quarter with reve...                   1
# 3  Tesla faced challenges in Q1 with declining au...                   1
# 4  Tesla faced significant challenges in Q2, part...                   0
# 5  NVIDIA reported a strong quarter with record r...                   1
# 6  NVIDIA reported a strong Q3 with record revenu...                   1
# 7  NVIDIA experienced a challenging quarter with ...                   1
# 8  NVIDIA reported a challenging quarter with sig...                   1
# 9  NVIDIA delivered a strong quarter with total r...                   1
#
#    revenue_outlook  margin_outlook  ...  risk_impact  risk_time_horizon  \
# 0                1               0  ...            1                  0
# 1                1               0  ...            1                  1
# 2                1               0  ...            1                  1
# 3                1               0  ...            1                  1
# 4                1               0  ...            1                  1
# 5                1               1  ...            1                  1
# 6                1               1  ...            1                  0
# 7                1               1  ...            1                  1
# 8                1               1  ...            1                  1
# 9                1               1  ...            1                  1
#
#                                         risk_factors  \
# 0  [regulatory burdens, China headwinds, foreign ...
# 1  [tariff-related costs, supply chain risk, lega...
# 2              [tariff rates, supply chain strategy]
# 3  [tariffs, geopolitical uncertainty, supply cha...
# 4     [tariff impacts, negative impacts of the bill]
# 5  [supply chain challenges, power supply concern...
# 6   [supply constraints, China business uncertainty]
# 7                              [tariffs uncertainty]
# 8  [export controls, China market limitations, in...
# 9  [geopolitical issues, supply chain uncertainties]
#
#                                         risk_summary mitigation_mentioned  \
# 0  Management highlighted significant risks inclu...                    1
# 1  Management highlighted significant risks relat...                    1
# 2  Management highlighted significant uncertainti...                    1
# 3  Management highlighted significant risks relat...                    1
# 4  Tesla is facing significant challenges due to ...                    1
# 5  Management highlighted significant risks relat...                    1
# 6  Management highlighted significant supply cons...                    1
# 7  Management highlighted the uncertainty surroun...                    1
# 8  NVIDIA faces significant risks due to stringen...                    1
# 9  NVIDIA faces significant uncertainties related...                    1
#
#   mitigation_effectiveness  mitigation_time_horizon  \
# 0                        1                        1
# 1                        1                        1
# 2                        1                        2
# 3                        1                        1
# 4                        0                        1
# 5                        1                        1
# 6                        1                        1
# 7                        0                        1
# 8                        0                        1
# 9                        1                        2
#
#                                   mitigation_actions  \
# 0  [expanding services offerings, capital return ...
# 1  [optimizing supply chain, engaging in tariff d...
# 2  [optimizing supply chain, investing $500 billi...
# 3  [regionalization of supply factories, local ma...
# 4  [pricing adjustments, investment in AI and rob...
# 5  [improving production yields, ramping up Black...
# 6  [compliance with export controls, expansion of...
# 7  [monitoring tariffs, compliance with export co...
# 8  [exploring limited ways to compete in the Chin...
# 9  [advocating for US government approval of Blac...
#
#                                   mitigation_summary  \
# 0  Management is actively expanding its services ...
# 1  Management is actively engaged in tariff discu...
# 2  Management is actively addressing tariff-relat...
# 3  Management is actively addressing global econo...
# 4  Tesla is addressing the challenges posed by ta...
# 5  Management is actively addressing supply chain...
# 6  Management is actively addressing risks relate...
# 7  Management acknowledged the uncertainty surrou...
# 8  NVIDIA is exploring limited ways to compete in...
# 9  NVIDIA is actively addressing geopolitical ris...
#
#                 last_updated
# 0 2025-10-11 18:24:59.077689
# 1 2025-10-11 18:24:59.077689
# 2 2025-10-11 18:24:59.077689
# 3 2025-10-11 18:24:59.077689
# 4 2025-10-11 18:24:59.077689
# 5 2025-10-11 18:24:59.077689
# 6 2025-10-11 18:24:59.077689
# 7 2025-10-11 18:24:59.077689
# 8 2025-10-11 18:24:59.077689
# 9 2025-10-11 18:24:59.077689
#
# [10 rows x 27 columns]
